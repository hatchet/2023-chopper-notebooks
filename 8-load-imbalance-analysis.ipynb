# %%
import hatchet as ht

gf_lulesh_analysis = ht.GraphFrame.from_hpctoolkit("/mnt/c/Users/onurc/Desktop/Work/Projects/chopper-data/quicksilver-hpctoolkit-128-fdef-database-2")

metrics = ["name", "REALTIME (sec) (E).imbalance", "REALTIME (sec) (E).ranks", "REALTIME (sec) (E).hist", "REALTIME (sec) (E).percentiles", "REALTIME (sec) (E).mean"]
gf_lulesh_analysis_res = gf_lulesh_analysis.load_imbalance(metric_column="REALTIME (sec) (E)", verbose=True)
gf_lulesh_analysis_res = gf_lulesh_analysis_res.dataframe[metrics]
gf_lulesh_analysis_res = gf_lulesh_analysis_res.head(50).sort_values("REALTIME (sec) (E).imbalance", ascending=False)

display(gf_lulesh_analysis_res.head(5))
# Out:
#                                                                              name  \
# node
# {'file': './src/g/g92/cankur1/annotated-apps/ca...  MacroscopicCrossSection.cc:22
# {'file': './src/g/g92/cankur1/annotated-apps/ca...  MacroscopicCrossSection.cc:32
# {'file': './src/g/g92/cankur1/annotated-apps/ca...             NuclearData.cc:270
# {'file': './src/g/g92/cankur1/annotated-apps/ca...                     MCT.cc:582
# {'file': './src/g/g92/cankur1/annotated-apps/ca...                     MCT.cc:587
#
#                                                     REALTIME (sec) (E).imbalance  \
# node
# {'file': './src/g/g92/cankur1/annotated-apps/ca...                      4.199311
# {'file': './src/g/g92/cankur1/annotated-apps/ca...                      1.539592
# {'file': './src/g/g92/cankur1/annotated-apps/ca...                      1.329530
# {'file': './src/g/g92/cankur1/annotated-apps/ca...                      1.319152
# ...
