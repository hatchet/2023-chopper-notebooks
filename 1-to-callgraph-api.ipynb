# %%
import hatchet as ht

simple_cct = [
    {
        "frame": {"name": "foo", "type": "function"},
        "metrics": {"time (inc)": 93.0, "time": 0.0},
        "children": [
            {
                "frame": {"name": "bar"},
                "metrics": {"time (inc)": 12.0, "time": 3.0},
                "children": [
                    {
                        "frame": {"name": "baz", "type": "function"},
                        "metrics": {"time (inc)": 3.0, "time": 3.0},
                    },
                    {
                        "frame": {"name": "grault"},
                        "metrics": {"time (inc)": 6.0, "time": 6.0},
                    },
                ],
            },
            {
                "frame": {"name": "qux", "type": "function"},
                "metrics": {"time (inc)": 43.0, "time": 0.0},
                "children": [
                    {
                        "frame": {"name": "quux"},
                        "metrics": {"time (inc)": 43.0, "time": 15.0},
                        "children": [
                            {
                                "frame": {"name": "corge", "type": "function"},
                                "metrics": {"time (inc)": 28.0, "time": 2.0},
                                "children": [
                                    {
                                        "frame": {"name": "bar"},
                                        "metrics": {
                                            "time (inc)": 8.0,
                                            "time": 2.0,
                                        },
                                        "children": [
                                            {
                                                "frame": {
                                                    "name": "baz",
                                                    "type": "function",
                                                },
                                                "metrics": {
                                                    "time (inc)": 3.0,
                                                    "time": 3.0,
                                                },
                                            },
                                            {
                                                "frame": {"name": "grault"},
                                     
                                                "metrics": {
                                                    "time (inc)": 3.0,
                                                    "time": 3.0,
                                                },
                                            },
                                        ],
                                    },
                                    {
                                        "frame": {"name": "grault"},
                                        "metrics": {
                                            "time (inc)": 6.0,
                                            "time": 6.0,
                                        },
                                    },
                                    {
                                        "frame": {
                                            "name": "garply",
                                            "type": "function",
                                        },
                                        "metrics": {
                                            "time (inc)": 12.0,
                                            "time": 12.0,
                                        },
                                    },
                                ],
                            }
                        ],
                    }
                ],
            },
            {
                "frame": {"name": "waldo", "type": "function"},
                "metrics": {"time (inc)": 38.0, "time": 3.0},
                "children": [
                    {
                        "frame": {"name": "fred", "type": "function"},
                        "metrics": {"time (inc)": 25.0, "time": 10.0},
                        "children": [
                            {
                                "frame": {"name": "plugh", "type": "function"},
                                "metrics": {"time (inc)": 10.0, "time": 10.0},
                            },
                            {
                                "frame": {"name": "xyzzy", "type": "function"},
                                "metrics": {"time (inc)": 15.0, "time": 3.0},
                                "children": [
                                    {
                                        "frame": {
                                            "name": "thud",
                                            "type": "function",
                                        },
                                        "metrics": {
                                            "time (inc)": 12.0,
                                            "time": 3.0,
                                        },
                                        "children": [
                                            {
                                                "frame": {
                                                    "name": "baz",
                                                    "type": "function",
                                                },
                                                "metrics": {
                                                    "time (inc)": 3.0,
                                                    "time": 3.0,
                                                },
                                            },
                                            {
                                                "frame": {
                                                    "name": "garply",
                                                    "type": "function",
                                                },
                                                "metrics": {
                                                    "time (inc)": 6.0,
                                                    "time": 6.0,
                                                },
                                            },
                                        ],
                                    }
                                ],
                            },
                        ],
                    },
                    {
                        "frame": {"name": "garply", "type": "function"},
                        "metrics": {"time (inc)": 10.0, "time": 10.0},
                    },
                ],
            },
        ],
    },
]

gf_to_callgraph = ht.GraphFrame.from_literal(simple_cct)
gf_to_callgraph.drop_index_levels()
gf_to_callgraph = gf_to_callgraph.to_callgraph()
